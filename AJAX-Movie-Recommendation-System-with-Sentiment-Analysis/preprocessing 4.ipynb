# %%
import pandas as pd
import numpy as np
import requests
import bs4 as bs
import urllib.request

# %% [markdown]
# ## Extracting features of 2020 movies from Wikipedia

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2020"

# %%
source = urllib.request.urlopen(link).read()
soup = bs.BeautifulSoup(source,'lxml')

# %%
tables = soup.find_all('table',class_='wikitable sortable')

# %%
len(tables)
# Out:
# 4

# %%
type(tables[0])
# Out:
# bs4.element.Tag

# %%
df1 = pd.read_html(str(tables[0]))[0]
df2 = pd.read_html(str(tables[1]))[0]
df3 = pd.read_html(str(tables[2]))[0]
df4 = pd.read_html(str(tables[3]).replace("'1\"\'",'"1"'))[0] # avoided "ValueError: invalid literal for int() with base 10: '1"'

# %%
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)

# %%
df
# Out:
#       Opening  Opening.1               Title  \
# 0     JANUARY          3          The Grudge
# 1     JANUARY         10          Underwater
# 2     JANUARY         10         Like a Boss
# 3     JANUARY         10   Inherit the Viper
# 4     JANUARY         10          The Sonata
# ..        ...        ...                 ...
# 205  DECEMBER         18          The Father
# 206  DECEMBER         25   Wonder Woman 1984
# 207  DECEMBER         25   News of the World
# 208  DECEMBER         25  One Night in Miami
# 209  DECEMBER         30      Monster Hunter
#
#                                     Production company  \
# 0    Screen Gems / Stage 6 Films / Ghost House Pict...
# 1    20th Century Fox / TSG Entertainment / Chernin...
# 2                                   Paramount Pictures
# 3       Barry Films / Tycor International Film Company
# 4                                   Screen Media Films
# ..                                                 ...
# 205                     Sony Pictures Classics / Film4
# 206  Warner Bros. Pictures / DC Films / Atlas Enter...
# 207                                 Universal Pictures
# 208                                     Amazon Studios
# 209  Screen Gems / Constantin Film / Impact Picture...
#
#                                          Cast and crew   Ref.
# 0    Nicolas Pesce (director/screenplay); Andrea Ri...    [2]
# 1    William Eubank (director); Brian Duffield, Ada...    [3]
# 2    Miguel Arteta (director); Sam Pitman, Adam Col...    [4]
# 3    Anthony Jerjen (director); Andrew Crabtree (sc...    [5]
# 4    Andrew Desmond (director/screenplay); Arthur M...    [6]
# ..                                                 ...    ...
# 205  Florian Zeller (director/screenplay); Christop...    NaN
# 206  Patty Jenkins (director/screenplay); Geoff Joh...  [194]
# 207  Paul Greengrass (director/screenplay); Luke Da...  [195]
# 208  Regina King (director); Kemp Powers (screenpla...  [196]
# 209  Paul W. S. Anderson (director/screenplay); Mil...  [197]
#
# [210 rows x 6 columns]

# %%
df_2020 = df[['Title','Cast and crew']]

# %%
df_2020
# Out:
#                   Title                                      Cast and crew
# 0            The Grudge  Nicolas Pesce (director/screenplay); Andrea Ri...
# 1            Underwater  William Eubank (director); Brian Duffield, Ada...
# 2           Like a Boss  Miguel Arteta (director); Sam Pitman, Adam Col...
# 3     Inherit the Viper  Anthony Jerjen (director); Andrew Crabtree (sc...
# 4            The Sonata  Andrew Desmond (director/screenplay); Arthur M...
# ..                  ...                                                ...
# 205          The Father  Florian Zeller (director/screenplay); Christop...
# 206   Wonder Woman 1984  Patty Jenkins (director/screenplay); Geoff Joh...
# 207   News of the World  Paul Greengrass (director/screenplay); Luke Da...
# 208  One Night in Miami  Regina King (director); Kemp Powers (screenpla...
# 209      Monster Hunter  Paul W. S. Anderson (director/screenplay); Mil...
#
# [210 rows x 2 columns]

# %%
from tmdbv3api import TMDb
import json
import requests
tmdb = TMDb()
tmdb.api_key = '53c045865cad0d8b981484db526fac2a'

# %%
from tmdbv3api import Movie
tmdb_movie = Movie()
def get_genre(x):
    genres = []
    result = tmdb_movie.search(x)
    movie_id = result[0].id
    response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key))
    data_json = response.json()
    if data_json['genres']:
        genre_str = " " 
        for i in range(0,len(data_json['genres'])):
            genres.append(data_json['genres'][i]['name'])
        return genre_str.join(genres)
    else:
        np.NaN

# %%
df_2020['genres'] = df_2020['Title'].map(lambda x: get_genre(str(x)))
# Out:
# C:\Users\harsh\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_2020
# Out:
#                   Title                                      Cast and crew  \
# 0            The Grudge  Nicolas Pesce (director/screenplay); Andrea Ri...
# 1            Underwater  William Eubank (director); Brian Duffield, Ada...
# 2           Like a Boss  Miguel Arteta (director); Sam Pitman, Adam Col...
# 3     Inherit the Viper  Anthony Jerjen (director); Andrew Crabtree (sc...
# 4            The Sonata  Andrew Desmond (director/screenplay); Arthur M...
# ..                  ...                                                ...
# 205          The Father  Florian Zeller (director/screenplay); Christop...
# 206   Wonder Woman 1984  Patty Jenkins (director/screenplay); Geoff Joh...
# 207   News of the World  Paul Greengrass (director/screenplay); Luke Da...
# 208  One Night in Miami  Regina King (director); Kemp Powers (screenpla...
# 209      Monster Hunter  Paul W. S. Anderson (director/screenplay); Mil...
#
#                                      genres
# 0                            Horror Mystery
# 1    Action Horror Science Fiction Thriller
# 2                                    Comedy
# 3                      Drama Thriller Crime
# 4                   Horror Thriller Mystery
# ..                                      ...
# 205                                   Drama
# 206                Fantasy Action Adventure
# 207                           Drama Western
# 208                                   Drama
# 209                Fantasy Action Adventure
#
# [210 rows x 3 columns]

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_2020['director_name'] = df_2020['Cast and crew'].map(lambda x: get_director(str(x)))
# Out:
# C:\Users\harsh\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2020['actor_1_name'] = df_2020['Cast and crew'].map(lambda x: get_actor1(str(x)))
# Out:
# C:\Users\harsh\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2020['actor_2_name'] = df_2020['Cast and crew'].map(lambda x: get_actor2(str(x)))

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2020['actor_3_name'] = df_2020['Cast and crew'].map(lambda x: get_actor3(str(x)))

# %%
df_2020
# Out:
#                   Title                                      Cast and crew  \
# 0            The Grudge  Nicolas Pesce (director/screenplay); Andrea Ri...
# 1            Underwater  William Eubank (director); Brian Duffield, Ada...
# 2           Like a Boss  Miguel Arteta (director); Sam Pitman, Adam Col...
# 3     Inherit the Viper  Anthony Jerjen (director); Andrew Crabtree (sc...
# 4            The Sonata  Andrew Desmond (director/screenplay); Arthur M...
# ..                  ...                                                ...
# 205          The Father  Florian Zeller (director/screenplay); Christop...
# 206   Wonder Woman 1984  Patty Jenkins (director/screenplay); Geoff Joh...
# 207   News of the World  Paul Greengrass (director/screenplay); Luke Da...
# 208  One Night in Miami  Regina King (director); Kemp Powers (screenpla...
# 209      Monster Hunter  Paul W. S. Anderson (director/screenplay); Mil...
#
#                                      genres        director_name  \
# 0                            Horror Mystery        Nicolas Pesce
# 1    Action Horror Science Fiction Thriller       William Eubank
# 2                                    Comedy        Miguel Arteta
# 3                      Drama Thriller Crime       Anthony Jerjen
# 4                   Horror Thriller Mystery       Andrew Desmond
# ..                                      ...                  ...
# 205                                   Drama       Florian Zeller
# 206                Fantasy Action Adventure        Patty Jenkins
# 207                           Drama Western      Paul Greengrass
# 208                                   Drama          Regina King
# 209                Fantasy Action Adventure  Paul W. S. Anderson
#
#            actor_1_name       actor_2_name       actor_3_name
# 0    Andrea Riseborough      Demián Bichir           John Cho
# 1       Kristen Stewart     Vincent Cassel    Jessica Henwick
# 2       Tiffany Haddish         Rose Byrne        Salma Hayek
# 3         Josh Hartnett  Margarita Levieva     Chandler Riggs
# 4         Freya Tingley     Simon Abkarian       Rutger Hauer
# ..                  ...                ...                ...
# 205     Anthony Hopkins      Olivia Colman        Mark Gatiss
# 206           Gal Gadot         Chris Pine       Kristen Wiig
# 207           Tom Hanks      Helena Zengel    Neil Sandilands
# 208   Kingsley Ben-Adir          Eli Goree        Aldis Hodge
# 209      Milla Jovovich           Tony Jaa  Tip "T.I." Harris
#
# [210 rows x 7 columns]

# %%
df_2020 = df_2020.rename(columns={'Title':'movie_title'})

# %%
new_df20 = df_2020.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df20
# Out:
#            director_name        actor_1_name       actor_2_name  \
# 0          Nicolas Pesce  Andrea Riseborough      Demián Bichir
# 1         William Eubank     Kristen Stewart     Vincent Cassel
# 2          Miguel Arteta     Tiffany Haddish         Rose Byrne
# 3         Anthony Jerjen       Josh Hartnett  Margarita Levieva
# 4         Andrew Desmond       Freya Tingley     Simon Abkarian
# ..                   ...                 ...                ...
# 205       Florian Zeller     Anthony Hopkins      Olivia Colman
# 206        Patty Jenkins           Gal Gadot         Chris Pine
# 207      Paul Greengrass           Tom Hanks      Helena Zengel
# 208          Regina King   Kingsley Ben-Adir          Eli Goree
# 209  Paul W. S. Anderson      Milla Jovovich           Tony Jaa
#
#           actor_3_name                                  genres  \
# 0             John Cho                          Horror Mystery
# 1      Jessica Henwick  Action Horror Science Fiction Thriller
# 2          Salma Hayek                                  Comedy
# 3       Chandler Riggs                    Drama Thriller Crime
# 4         Rutger Hauer                 Horror Thriller Mystery
# ..                 ...                                     ...
# 205        Mark Gatiss                                   Drama
# 206       Kristen Wiig                Fantasy Action Adventure
# 207    Neil Sandilands                           Drama Western
# 208        Aldis Hodge                                   Drama
# 209  Tip "T.I." Harris                Fantasy Action Adventure
#
#             movie_title
# 0            The Grudge
# 1            Underwater
# 2           Like a Boss
# 3     Inherit the Viper
# 4            The Sonata
# ..                  ...
# 205          The Father
# 206   Wonder Woman 1984
# 207   News of the World
# 208  One Night in Miami
# 209      Monster Hunter
#
# [210 rows x 6 columns]

# %%
new_df20['comb'] = new_df20['actor_1_name'] + ' ' + new_df20['actor_2_name'] + ' '+ new_df20['actor_3_name'] + ' '+ new_df20['director_name'] +' ' + new_df20['genres']

# %%
new_df20.isna().sum()
# Out:
# director_name     0
# actor_1_name      0
# actor_2_name      2
# actor_3_name     20
# genres            1
# movie_title       0
# comb             21
# dtype: int64

# %%
new_df20 = new_df20.dropna(how='any')

# %%
new_df20.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# comb             0
# dtype: int64

# %%
new_df20['movie_title'] = new_df20['movie_title'].str.lower()
# Out:
# C:\Users\harsh\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
new_df20
# Out:
#            director_name        actor_1_name       actor_2_name  \
# 0          Nicolas Pesce  Andrea Riseborough      Demián Bichir
# 1         William Eubank     Kristen Stewart     Vincent Cassel
# 2          Miguel Arteta     Tiffany Haddish         Rose Byrne
# 3         Anthony Jerjen       Josh Hartnett  Margarita Levieva
# 4         Andrew Desmond       Freya Tingley     Simon Abkarian
# ..                   ...                 ...                ...
# 205       Florian Zeller     Anthony Hopkins      Olivia Colman
# 206        Patty Jenkins           Gal Gadot         Chris Pine
# 207      Paul Greengrass           Tom Hanks      Helena Zengel
# 208          Regina King   Kingsley Ben-Adir          Eli Goree
# 209  Paul W. S. Anderson      Milla Jovovich           Tony Jaa
#
#           actor_3_name                                  genres  \
# 0             John Cho                          Horror Mystery
# 1      Jessica Henwick  Action Horror Science Fiction Thriller
# 2          Salma Hayek                                  Comedy
# 3       Chandler Riggs                    Drama Thriller Crime
# 4         Rutger Hauer                 Horror Thriller Mystery
# ..                 ...                                     ...
# 205        Mark Gatiss                                   Drama
# 206       Kristen Wiig                Fantasy Action Adventure
# 207    Neil Sandilands                           Drama Western
# 208        Aldis Hodge                                   Drama
# 209  Tip "T.I." Harris                Fantasy Action Adventure
#
#             movie_title                                               comb
# 0            the grudge  Andrea Riseborough Demián Bichir John Cho Nico...
# 1            underwater  Kristen Stewart Vincent Cassel Jessica Henwick...
# 2           like a boss  Tiffany Haddish Rose Byrne Salma Hayek Miguel ...
# 3     inherit the viper  Josh Hartnett Margarita Levieva Chandler Riggs...
# 4            the sonata  Freya Tingley Simon Abkarian Rutger Hauer Andr...
# ..                  ...                                                ...
# 205          the father  Anthony Hopkins Olivia Colman Mark Gatiss Flor...
# 206   wonder woman 1984  Gal Gadot Chris Pine Kristen Wiig Patty Jenkin...
# 207   news of the world  Tom Hanks Helena Zengel Neil Sandilands Paul G...
# 208  one night in miami  Kingsley Ben-Adir Eli Goree Aldis Hodge Regina...
# 209      monster hunter  Milla Jovovich Tony Jaa Tip "T.I." Harris Paul...
#
# [189 rows x 7 columns]

# %%
old_df = pd.read_csv('final_data.csv')

# %%
old_df
# Out:
#               director_name       actor_1_name          actor_2_name  \
# 0             James Cameron        CCH Pounder      Joel David Moore
# 1            Gore Verbinski        Johnny Depp         Orlando Bloom
# 2                Sam Mendes    Christoph Waltz          Rory Kinnear
# 3         Christopher Nolan          Tom Hardy        Christian Bale
# 4               Doug Walker        Doug Walker            Rob Walker
# ...                     ...                ...                   ...
# 5864           Greta Gerwig      Saoirse Ronan           Emma Watson
# 5865             Sam Mendes      George MacKay  Dean-Charles Chapman
# 5866  Destin Daniel Cretton  Michael B. Jordan            Jamie Foxx
# 5867        Chinonye Chukwu      Alfre Woodard        Wendell Pierce
# 5868           Waymon Boone        Mena Suvari          Kevin Pollak
#
#               actor_3_name                           genres  \
# 0                Wes Studi  Action Adventure Fantasy Sci-Fi
# 1           Jack Davenport         Action Adventure Fantasy
# 2         Stephanie Sigman        Action Adventure Thriller
# 3     Joseph Gordon-Levitt                  Action Thriller
# 4                  unknown                      Documentary
# ...                    ...                              ...
# 5864         Florence Pugh                    Drama Romance
# 5865           Mark Strong         War Drama Action History
# 5866           Brie Larson                      Drama Crime
# 5867           Aldis Hodge                            Drama
# 5868               unknown                  Horror Thriller
#
#                                             movie_title  \
# 0                                                avatar
# 1              pirates of the caribbean: at world's end
# 2                                               spectre
# 3                                 the dark knight rises
# 4     star wars: episode vii - the force awakens    ...
# ...                                                 ...
# 5864                                       little women
# 5865                                               1917
# 5866                                         just mercy
# 5867                                           clemency
# 5868                                         apparition
#
#                                                    comb
# 0     CCH Pounder Joel David Moore Wes Studi James C...
# 1     Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2     Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3     Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4     Doug Walker Rob Walker unknown Doug Walker Doc...
# ...                                                 ...
# 5864  Saoirse Ronan Emma Watson Florence Pugh Greta ...
# 5865  George MacKay Dean-Charles Chapman Mark Strong...
# 5866  Michael B. Jordan Jamie Foxx Brie Larson Desti...
# 5867  Alfre Woodard Wendell Pierce Aldis Hodge Chino...
# 5868  Mena Suvari Kevin Pollak unknown Waymon Boone ...
#
# [5869 rows x 7 columns]

# %%
final_df = old_df.append(new_df20,ignore_index=True)

# %%
final_df
# Out:
#             director_name       actor_1_name      actor_2_name  \
# 0           James Cameron        CCH Pounder  Joel David Moore
# 1          Gore Verbinski        Johnny Depp     Orlando Bloom
# 2              Sam Mendes    Christoph Waltz      Rory Kinnear
# 3       Christopher Nolan          Tom Hardy    Christian Bale
# 4             Doug Walker        Doug Walker        Rob Walker
# ...                   ...                ...               ...
# 6053       Florian Zeller    Anthony Hopkins     Olivia Colman
# 6054        Patty Jenkins          Gal Gadot        Chris Pine
# 6055      Paul Greengrass          Tom Hanks     Helena Zengel
# 6056          Regina King  Kingsley Ben-Adir         Eli Goree
# 6057  Paul W. S. Anderson     Milla Jovovich          Tony Jaa
#
#               actor_3_name                           genres  \
# 0                Wes Studi  Action Adventure Fantasy Sci-Fi
# 1           Jack Davenport         Action Adventure Fantasy
# 2         Stephanie Sigman        Action Adventure Thriller
# 3     Joseph Gordon-Levitt                  Action Thriller
# 4                  unknown                      Documentary
# ...                    ...                              ...
# 6053           Mark Gatiss                            Drama
# 6054          Kristen Wiig         Fantasy Action Adventure
# 6055       Neil Sandilands                    Drama Western
# 6056           Aldis Hodge                            Drama
# 6057     Tip "T.I." Harris         Fantasy Action Adventure
#
#                                             movie_title  \
# 0                                                avatar
# 1              pirates of the caribbean: at world's end
# 2                                               spectre
# 3                                 the dark knight rises
# 4     star wars: episode vii - the force awakens    ...
# ...                                                 ...
# 6053                                         the father
# 6054                                  wonder woman 1984
# 6055                                  news of the world
# 6056                                 one night in miami
# 6057                                     monster hunter
#
#                                                    comb
# 0     CCH Pounder Joel David Moore Wes Studi James C...
# 1     Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2     Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3     Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4     Doug Walker Rob Walker unknown Doug Walker Doc...
# ...                                                 ...
# 6053  Anthony Hopkins Olivia Colman Mark Gatiss Flor...
# 6054  Gal Gadot Chris Pine Kristen Wiig Patty Jenkin...
# 6055  Tom Hanks Helena Zengel Neil Sandilands Paul G...
# 6056  Kingsley Ben-Adir Eli Goree Aldis Hodge Regina...
# 6057  Milla Jovovich Tony Jaa Tip "T.I." Harris Paul...
#
# [6058 rows x 7 columns]

# %%
final_df.to_csv('main_data.csv',index=False)
